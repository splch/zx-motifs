# %% [markdown]
# # 01 — Conversion Explorer
#
# Convert quantum algorithms to ZX diagrams at multiple simplification levels.
# Build intuition for how ZX rewrites reshape algorithmic structure.

# %%
import pandas as pd
import pyzx as zx
import matplotlib.pyplot as plt

from zx_motifs.algorithms.registry import REGISTRY
from zx_motifs.pipeline.converter import convert_at_all_levels
from zx_motifs.pipeline.featurizer import pyzx_to_networkx, compute_graph_features

# %% [markdown]
# ## Batch Conversion
#
# Convert every algorithm in the registry at multiple qubit counts.

# %%
all_snapshots = []
for entry in REGISTRY:
    min_q, max_q = entry.qubit_range
    for n in range(min_q, min(max_q + 1, 10)):  # Cap at 9 qubits for exploration
        try:
            qc = entry.generator(n_qubits=n)
            snaps = convert_at_all_levels(qc, f"{entry.name}_q{n}")
            all_snapshots.extend(snaps)
            print(f"  {entry.name} (n={n}): {len(snaps)} snapshots")
        except Exception as e:
            print(f"  {entry.name} (n={n}): FAILED — {e}")

print(f"\nTotal snapshots: {len(all_snapshots)}")
# Out:
#   bell_state (n=2): 6 snapshots
#   bell_state (n=3): 6 snapshots
#   bell_state (n=4): 6 snapshots
#   bell_state (n=5): 6 snapshots
#   bell_state (n=6): 6 snapshots
#   bell_state (n=7): 6 snapshots
#   bell_state (n=8): 6 snapshots
#   ghz_state (n=3): 6 snapshots
#   ghz_state (n=4): 6 snapshots
#   ghz_state (n=5): 6 snapshots
#   ghz_state (n=6): 6 snapshots
#   ghz_state (n=7): 6 snapshots
#   ghz_state (n=8): 6 snapshots
#   teleportation (n=3): 6 snapshots
#   qft (n=2): 6 snapshots
#   qft (n=3): 6 snapshots
#   qft (n=4): 6 snapshots
#   qft (n=5): 6 snapshots
#   qft (n=6): 6 snapshots
#   qft (n=7): 6 snapshots
#   grover (n=3): 6 snapshots
#   grover (n=4): 6 snapshots
#   grover (n=5): 6 snapshots
#   grover (n=6): FAILED — Arguments for custom gates are currently not supported: mcphase(param0) q0,q1,q2,q3,q4,q5 { h q5; p(pi/8) q0; p(pi/8) q1; p(pi/8) q2; p(pi/8) q5; cx q0,q1; p(-pi/8) q1; cx q0,q1; cx q1,q2; p(-pi/8) q2; cx q0,q2; p(pi/8) q2; cx q1,q2; p(-pi/8) q2; cx q0,q2; cx q2,q5; p(-pi/8) q5; cx q1,q5; p(pi/8) q5; cx q2,q5; p(-pi/8) q5; cx q0,q5; p(pi/8) q5; cx q2,q5; p(-pi/8) q5; cx q1,q5; p(pi/8) q5; cx q2,q5; p(-pi/8) q5; cx q0,q5; h q5; rz(-pi/4) q5; h q5; cx q4,q5; tdg q5; cx q3,q5; t q5; cx q4,q5; tdg q5; cx q3,q5; t q4; t q5; h q5; cx q3,q4; t q3; tdg q4; cx q3,q4; rz(pi/4) q5; h q5; p(pi/8) q0; p(pi/8) q1; p(pi/8) q2; p(pi/8) q5; cx q0,q1; p(-pi/8) q1; cx q0,q1; cx q1,q2; p(-pi/8) q2; cx q0,q2; p(pi/8) q2; cx q1,q2; p(-pi/8) q2; cx q0,q2; cx q2,q5; p(-pi/8) q5; cx q1,q5; p(pi/8) q5; cx q2,q5; p(-pi/8) q5; cx q0,q5; p(pi/8) q5; cx q2,q5; p(-pi/8) q5; cx q1,q5; p(pi/8) q5; cx q2,q5; p(-pi/8) q5; cx q0,q5; h q5; rz(-pi/4) q5; h q5; cx q4,q5; tdg q5; cx q3,q5; t q5; cx q4,q5; tdg q5; cx q3,q5; t q4; t q5; h q5; cx q3,q4; t q3; tdg q4; cx q3,q4; rz(pi/4) q5; h q4; cx q1,q4; tdg q4; cx q0,q4; t q4; cx q1,q4; tdg q4; cx q0,q4; t q1; t q4; h q4; cx q0,q1; t q0; tdg q1; cx q0,q1; rz(-pi/8) q4; h q4; cx q3,q4; tdg q4; cx q2,q4; t q4; cx q3,q4; tdg q4; cx q2,q4; t q3; t q4; h q4; cx q2,q3; t q2; tdg q3; cx q2,q3; rz(pi/8) q4; h q4; cx q1,q4; tdg q4; cx q0,q4; t q4; cx q1,q4; tdg q4; cx q0,q4; t q1; t q4; h q4; cx q0,q1; t q0; tdg q1; cx q0,q1; rz(-pi/8) q4; h q4; cx q3,q4; tdg q4; cx q2,q4; t q4; cx q3,q4; tdg q4; cx q2,q4; t q3; t q4; h q4; cx q2,q3; t q2; tdg q3; cx q2,q3; rz(pi/8) q4; h q3; cx q1,q3; tdg q3; cx q0,q3; t q3; cx q1,q3; tdg q3; cx q0,q3; t q1; t q3; h q3; cx q0,q1; t q0; tdg q1; cx q0,q1; rz(-pi/16) q3; cx q2,q3; rz(pi/16) q3; h q3; cx q1,q3; tdg q3; cx q0,q3; t q3; cx q1,q3; tdg q3; cx q0,q3; t q1; t q3; h q3; cx q0,q1; t q0; tdg q1; cx q0,q1; rz(-pi/16) q3; cx q2,q3; rz(pi/16) q3; cx q0,q2; rz(-pi/32) q2; cx q1,q2; rz(pi/32) q2; cx q0,q2; rz(-pi/32) q2; cx q1,q2; rz(pi/32) q2; crz(pi/16) q0,q1; p(pi/32) q0; }
#   bernstein_vazirani (n=3): 6 snapshots
#   bernstein_vazirani (n=4): 6 snapshots
#   bernstein_vazirani (n=5): 6 snapshots
#   bernstein_vazirani (n=6): 6 snapshots
#   deutsch_jozsa (n=2): 6 snapshots
#   deutsch_jozsa (n=3): 6 snapshots
#   deutsch_jozsa (n=4): 6 snapshots
#   deutsch_jozsa (n=5): 6 snapshots
#   deutsch_jozsa (n=6): 6 snapshots
#   phase_estimation (n=4): 6 snapshots
#   phase_estimation (n=5): 6 snapshots
#   phase_estimation (n=6): 6 snapshots
#   phase_estimation (n=7): 6 snapshots
#   phase_estimation (n=8): 6 snapshots
#   qaoa_maxcut (n=3): 6 snapshots
#   qaoa_maxcut (n=4): 6 snapshots
#   qaoa_maxcut (n=5): 6 snapshots
#   qaoa_maxcut (n=6): 6 snapshots
#   qaoa_maxcut (n=7): 6 snapshots
#   qaoa_maxcut (n=8): 6 snapshots
#   vqe_uccsd (n=4): 6 snapshots
#   hw_efficient_ansatz (n=3): 6 snapshots
#   hw_efficient_ansatz (n=4): 6 snapshots
#   hw_efficient_ansatz (n=5): 6 snapshots
#   hw_efficient_ansatz (n=6): 6 snapshots
#   hw_efficient_ansatz (n=7): 6 snapshots
#   hw_efficient_ansatz (n=8): 6 snapshots
#   bit_flip_code (n=5): 6 snapshots
#   phase_flip_code (n=5): 6 snapshots
#   steane_code (n=7): 6 snapshots
#   trotter_ising (n=2): 6 snapshots
#   trotter_ising (n=3): 6 snapshots
#   trotter_ising (n=4): 6 snapshots
#   trotter_ising (n=5): 6 snapshots
#   trotter_ising (n=6): 6 snapshots
#   trotter_ising (n=7): 6 snapshots
#   trotter_ising (n=8): 6 snapshots
#   trotter_heisenberg (n=2): 6 snapshots
#   trotter_heisenberg (n=3): 6 snapshots
#   trotter_heisenberg (n=4): 6 snapshots
#   trotter_heisenberg (n=5): 6 snapshots
#   trotter_heisenberg (n=6): 6 snapshots
#   trotter_heisenberg (n=7): 6 snapshots
#   trotter_heisenberg (n=8): 6 snapshots
#   ripple_carry_adder (n=5): 6 snapshots
#   simon (n=4): 6 snapshots
#   simon (n=5): 6 snapshots
#   simon (n=6): 6 snapshots
#   simon (n=7): 6 snapshots
#   simon (n=8): 6 snapshots
#   w_state (n=3): 6 snapshots
#   w_state (n=4): 6 snapshots
#   w_state (n=5): 6 snapshots
#   w_state (n=6): 6 snapshots
#   w_state (n=7): 6 snapshots
#   w_state (n=8): 6 snapshots
#   cluster_state (n=2): 6 snapshots
#   cluster_state (n=3): 6 snapshots
#   cluster_state (n=4): 6 snapshots
#   cluster_state (n=5): 6 snapshots
#   cluster_state (n=6): 6 snapshots
#   cluster_state (n=7): 6 snapshots
#   cluster_state (n=8): 6 snapshots
#   superdense_coding (n=2): 6 snapshots
#   shor_code (n=9): 6 snapshots
#   quantum_walk (n=3): 6 snapshots
#   quantum_walk (n=4): 6 snapshots
#   quantum_walk (n=5): 6 snapshots
#   quantum_walk (n=6): 6 snapshots
#   qft_adder (n=4): 6 snapshots
#   qft_adder (n=5): 6 snapshots
#   qft_adder (n=6): 6 snapshots
#   qft_adder (n=7): 6 snapshots
#   qft_adder (n=8): 6 snapshots
#   quantum_counting (n=5): 6 snapshots
#   quantum_counting (n=6): 6 snapshots
#   quantum_counting (n=7): 6 snapshots
#   quantum_counting (n=8): 6 snapshots
#   entanglement_swapping (n=4): 6 snapshots
#   bbpssw_distillation (n=4): 6 snapshots
#   dejmps_distillation (n=4): 6 snapshots
#   recurrence_distillation (n=8): 6 snapshots
#   pumping_distillation (n=6): 6 snapshots
#   quantum_kernel (n=2): 6 snapshots
#   quantum_kernel (n=3): 6 snapshots
#   quantum_kernel (n=4): 6 snapshots
#   quantum_kernel (n=5): 6 snapshots
#   quantum_kernel (n=6): 6 snapshots
#   quantum_kernel (n=7): 6 snapshots
#   quantum_kernel (n=8): 6 snapshots
#   data_reuploading (n=2): 6 snapshots
#   data_reuploading (n=3): 6 snapshots
#   data_reuploading (n=4): 6 snapshots
#   data_reuploading (n=5): 6 snapshots
#   data_reuploading (n=6): 6 snapshots
#
# Total snapshots: 708

# %% [markdown]
# ## Summary Statistics

# %%
rows = [s.to_dict() for s in all_snapshots]
df = pd.DataFrame(rows)
print(df.groupby("level")[["vertices", "edges", "t_gates"]].mean().round(1))
# Out:
#                  vertices  edges  t_gates
# level
# clifford_simp        29.3   43.1      1.9
# full_reduce          26.6   34.9      1.5
# interior_cliff       29.7   39.2      2.1
# raw                  61.1   69.2      2.5
# spider_fused         43.4   51.0      2.2
# teleport_reduce      61.1   69.2      1.7

# %% [markdown]
# ## Simplification Cascade Visualization
#
# Pick one algorithm and visualize how each simplification level transforms it.

# %%
from zx_motifs.pipeline.featurizer import pyzx_to_networkx

target_algo = "grover_q3"
target_snaps = [s for s in all_snapshots if s.algorithm_name == target_algo]

if target_snaps:
    import networkx as nx

    color_map = {"Z": "#00cc00", "X": "#cc0000", "H_BOX": "#cccc00", "BOUNDARY": "#888888"}

    fig, axes = plt.subplots(2, 3, figsize=(20, 12))
    for ax, snap in zip(axes.flat, target_snaps):
        ax.set_title(f"{snap.level.value}\nV={snap.num_vertices} E={snap.num_edges}")

        nxg = pyzx_to_networkx(snap.graph, coarsen_phases=True)
        pos = nx.spring_layout(nxg, seed=42)
        colors = [
            color_map.get(nxg.nodes[n].get("vertex_type", "?"), "#0000cc")
            for n in nxg.nodes()
        ]

        for u, v, d in nxg.edges(data=True):
            style = "dashed" if d.get("edge_type") == "HADAMARD" else "solid"
            nx.draw_networkx_edges(nxg, pos, edgelist=[(u, v)], style=style, ax=ax)

        nx.draw_networkx_nodes(nxg, pos, node_color=colors, node_size=200, ax=ax)
        ax.axis("off")

    plt.suptitle(f"Simplification Cascade: {target_algo}", fontsize=16)
    plt.tight_layout()
    plt.savefig("simplification_cascade.png", dpi=150)
    plt.show()
else:
    print(f"Algorithm '{target_algo}' not found in snapshots.")

# %% [markdown]
# ## Feature Extraction & Clustering

# %%
# Convert all snapshots to NetworkX and compute features
feature_rows = []
nx_graphs = {}  # (algo_name, level) -> nx.Graph

for snap in all_snapshots:
    nxg = pyzx_to_networkx(snap.graph, coarsen_phases=True)
    key = (snap.algorithm_name, snap.level.value)
    nx_graphs[key] = nxg

    feats = compute_graph_features(nxg)
    feats["algorithm"] = snap.algorithm_name
    feats["level"] = snap.level.value
    feature_rows.append(feats)

feat_df = pd.DataFrame(feature_rows)
print(feat_df[["algorithm", "level", "n_nodes", "n_edges",
               "hadamard_ratio", "avg_degree"]].head(20).to_string())
# Out:
#         algorithm            level  n_nodes  n_edges  hadamard_ratio  avg_degree
# 0   bell_state_q2              raw        7        6        0.166667    1.714286
# 1   bell_state_q2     spider_fused        6        5        0.200000    1.666667
# 2   bell_state_q2   interior_cliff        6        5        0.800000    1.666667
# 3   bell_state_q2    clifford_simp        6        5        0.800000    1.666667
# 4   bell_state_q2      full_reduce        6        5        0.800000    1.666667
# 5   bell_state_q2  teleport_reduce        7        6        0.166667    1.714286
# 6   bell_state_q3              raw       11       10        0.100000    1.818182
# 7   bell_state_q3     spider_fused        9        8        0.125000    1.777778
# 8   bell_state_q3   interior_cliff        9        8        0.875000    1.777778
# 9   bell_state_q3    clifford_simp        9        8        0.875000    1.777778
# 10  bell_state_q3      full_reduce        9        8        0.875000    1.777778
# 11  bell_state_q3  teleport_reduce       11       10        0.100000    1.818182
# 12  bell_state_q4              raw       15       14        0.071429    1.866667
# 13  bell_state_q4     spider_fused       12       11        0.090909    1.833333
# 14  bell_state_q4   interior_cliff       12       11        0.909091    1.833333
# 15  bell_state_q4    clifford_simp       12       11        0.909091    1.833333
# 16  bell_state_q4      full_reduce       12       11        0.909091    1.833333
# 17  bell_state_q4  teleport_reduce       15       14        0.071429    1.866667
# 18  bell_state_q5              raw       19       18        0.055556    1.894737
# 19  bell_state_q5     spider_fused       15       14        0.071429    1.866667

# %%
try:
    import seaborn as sns

    spider_df = feat_df[feat_df["level"] == "spider_fused"].copy()
    cluster_cols = ["n_nodes", "n_edges", "hadamard_ratio", "avg_degree", "density"]
    available_cols = [c for c in cluster_cols if c in spider_df.columns]

    if len(available_cols) >= 2:
        # Extract base algorithm name for hue
        spider_df["algo_base"] = spider_df["algorithm"].str.rsplit("_q", n=1).str[0]
        sns.pairplot(spider_df, vars=available_cols, hue="algo_base", diag_kind="hist")
        plt.suptitle("ZX Graph Feature Space (Spider-Fused Level)", y=1.02)
        plt.savefig("feature_clustering.png", dpi=150)
        plt.show()
except ImportError:
    print("Install seaborn for clustering visualization: pip install seaborn")

# %% [markdown]
# ## Observation Log
#
# Fill this in as you explore — building intuition is the goal.
#
# ```
# OBSERVATION LOG:
#
# 1. [algo] at [level]: noticed [pattern]
#    Example: "grover_q3 at spider_fused: the oracle and diffusion
#    operator produce symmetric Z-spider clusters connected by
#    Hadamard edges — the two clusters are near-identical up to phase"
#
# 2. ...
# ```
